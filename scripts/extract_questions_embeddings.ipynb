# %% [markdown]
# # Preparation

# %% [markdown]
# Installing and importing libraries

# %%
# # install correct version of tensorflow
# !pip install tensorflow==2.1
# # install libraries if needed
# !pip install sentence_transformers

# %%
import tensorflow_hub as hub
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.preprocessing import Normalizer
from sentence_transformers import SentenceTransformer

# %% [markdown]
# Set Dataset paths

# %%
# dataset paths
dataset = 'seven'
questionnaire = "rbq"
dataset_path = '../embeddings/'
responses_file_name = "".join([dataset, "/", questionnaire.upper(), "/", questionnaire.lower(), "_responses_nonReversed.csv"])
output_embeddings_file_name = "".join([dataset, "/", questionnaire.upper(), "/", questionnaire.lower(), "_questions_embeddings_SENTENCEBERT.csv"])

# %% [markdown]
# Loading item text (output format should be consistent for both Big5 dataset and IPIP dataset)

# %%
#load item-response matrix
matrix = pd.read_csv(dataset_path + responses_file_name, header = 0)
print(matrix[-5:])

# preprocess data
# ATTENTION: check if item has "I" or not! If not, manually add "I"
matrix['item'] = [(item).lower() for item in matrix['item']]

# extract data
question_ids = matrix['question_id']
individual_ys = matrix.drop(['question_id'], axis=1).set_index(["item"]).T
items = matrix.iloc[:,1].tolist()
print(items)
print(len(items))
# Out:
#    question_id                                               item    0    1  \
# 63      rbq064           Concentrates on or works hard at a task.  8.0  3.0
# 64      rbq065  Engages in physical activity. (e.g., works up ...  1.0  3.0
# 65      rbq066  Acts in a self-indulgent manner. (e.g., spendi...  6.0  2.0
# 66      rbq067  Exhibits physical discomfort or pain. (High pl...  1.0  1.0
# 67      rbq068  Behaves in a stereotypically feminine style or...  2.0  1.0
#
#       2    3    4    5    6    7  ...  5966  5967  5968  5969  5970  5971  \
# 63  2.0  7.0  6.0  6.0  3.0  3.0  ...   5.0   9.0   9.0   4.0   9.0   5.0
# 64  2.0  9.0  1.0  9.0  3.0  1.0  ...   2.0   2.0   9.0   3.0   2.0   2.0
# 65  5.0  4.0  5.0  5.0  5.0  1.0  ...   6.0   4.0   8.0   8.0   1.0   9.0
# 66  5.0  4.0  1.0  2.0  4.0  5.0  ...   6.0   7.0   2.0   4.0   2.0   1.0
# 67  1.0  8.0  3.0  6.0  5.0  2.0  ...   5.0   5.0   2.0   3.0   1.0   1.0
#
#     5972  5973  5974  5975
# 63   4.0   5.0   1.0   8.0
# 64   1.0   3.0   7.0   5.0
# 65   9.0   5.0   5.0   6.0
# 66   1.0   5.0   5.0   5.0
# 67   9.0   5.0   5.0   4.0
#
# [5 rows x 5971 columns]
# ['interviews others (if present). (e.g., asks a series of questions)', 'volunteers a large amount of information about self.', 'seems interested in what someone had to say.', 'tries to control the situation. (disregard whether attempts at control succeed or not.)', 'dominates the situation. (disregard intention, e.g., if p dominates the situation by default because other(s) present does very little, this item should receive high placement.)', 'appears to be relaxed and comfortable.', 'exhibits social skills. (e.g., makes other(s) comfortable, keeps conversation moving, entertains or charms other(s))', 'is reserved and unexpressive. (e.g., expresses little affect; acts in a stiff, formal manner)', 'laughs frequently. (disregard whether laughter appears to be nervous or genuine.)', 'smiles frequently.', 'is physically animated; moves around.', 'seems to like other(s) present. (e.g., would probably like to be friends with them)', 'exhibits an awkward interpersonal style. (e.g., seems to have difficulty knowing what to say, mumbles, fails to respond to conversational advances)', 'compares self to other(s). (whether others are present or not)', 'shows high enthusiasm and a high energy level.', 'shows a wide range of interests. (e.g., talks about many topics)', 'talks at rather than with other(s). (e.g., conducts a monologue, ignores what other(s) says)', 'expresses agreement frequently. (high placement = agreement is expressed unusually often, e.g., in response to each and every statement partner(s) makes. low placement = unusual lack of expression of agreement.)', 'expresses criticism. (of anybody or anything) (low placement = expresses praise.)', 'is talkative. (as observed in this situation)', 'expresses insecurity. (e.g., seems touchy or overly sensitive)', 'show physical signs of tension or anxiety. (e.g., fidgets nervously, voice wavers) (middle placement = lack of signs of anxiety. low placement = lack of signs under circumstances where you would expect them.)', 'exhibits a high degree of intelligence (give this item high placement only if p actually says or does something of high intelligence. low placement = exhibition of low intelligence. medium placement = no information one way or another.)', 'expresses sympathy. (to anyone, i.e., including conversational references) (low placement = unusual lack of sympathy.)', 'initiates humor.', 'seeks reassurance. (e.g., asks for agreement, fishes for praise)', 'exhibits condescending behavior. (e.g., acts as if self is superior to other(s) [present, or otherwise]) (low placement = acting inferior.)', 'seems likable. (to other(s) present)', 'seeks advice.', 'appears to regard self as physically attractive.', 'acts irritated.', 'expresses warmth. (to anyone, e.g., including affectionate references to close friends, ect.)', 'tries to undermine, sabotage or obstruct.', 'expresses hostility. (no matter toward whom or what)', 'is unusual or unconventional in appearance.', 'behaves in a fearful or timid manner.', 'is expressive in face, voice or gestures.', 'expresses interest in fantasy or daydreams. (low placement only if such interest is explicitly disavowed.)', 'expresses guilt. (about anything)', 'keeps other(s) at a distance; avoids development of any sort of interpersonal relationship. (low placement = behavior to get close to other(s).)', 'shows interest in intellectual or cognitive matters. (discusses an intellectual idea in detail or with enthusiasm)', 'seems to enjoy the situation.', 'says or does something interesting.', 'says negative things about self. (e.g., is self-critical; expresses feelings of inadequacy)', 'displays ambition. (e.g., passionate discussion of career plans, course grades, opportunities to make money)', 'blames others. (for anything)', 'expresses self-pity or feelings of victimization.', 'expresses sexual interest. (e.g., acts attracted to someone present; expresses interest in dating or sexual matters in general)', 'behaves in a cheerful manner.', 'gives  ...
# 68

# %% [markdown]
# # Extract embeddings

# %% [markdown]
# Extracting sentence-BERT embeddings.

# %%
## sentence-BERT
# model = SentenceTransformer('roberta-large-nli-stsb-mean-tokens')
# model = SentenceTransformer('all-MiniLM-L12-v2')
model = SentenceTransformer('all-mpnet-base-v2')
sentence_embeddings = model.encode(items)
vec = sentence_embeddings
print(vec.shape)
# Out:
# (68, 768)

# %% [markdown]
# # Save to files

# %%
print(vec.shape)
embeddings_df = pd.DataFrame(vec)
embeddings_df.insert(0,'question_id', question_ids)
embeddings_df.columns = ['question_id'] + list(range(vec.shape[1]))
print("saving to file: " + dataset_path + output_embeddings_file_name)
print(embeddings_df.head())
embeddings_df.to_csv(dataset_path + output_embeddings_file_name, index = False, header = True)
# Out:
# (68, 768)
# saving to file: ../embeddings/seven/RBQ/rbq_questions_embeddings_SENTENCEBERT.csv
#   question_id         0         1         2         3         4         5  \
# 0      rbq001  0.044745  0.001965 -0.016740  0.034363 -0.089471 -0.012975
# 1      rbq002  0.049429  0.072673  0.003481 -0.004440  0.022819  0.004320
# 2      rbq003 -0.004291  0.089111  0.013607 -0.007228 -0.105615  0.006196
# 3      rbq004  0.044867 -0.038076 -0.006002 -0.008826 -0.073893  0.001470
# 4      rbq005  0.003389 -0.064028 -0.009089  0.009025 -0.040007 -0.016604
#
#           6         7         8  ...       758       759       760       761  \
# 0  0.043938 -0.048950 -0.006987  ...  0.082882 -0.057834  0.020197  0.022347
# 1 -0.007476 -0.026199  0.015136  ...  0.020008 -0.010176 -0.057272  0.007057
# 2  0.016123  0.017257 -0.004818  ...  0.018837  0.059451  0.009165  0.018991
# 3 -0.022699  0.001197  0.010874  ... -0.032847  0.025618 -0.048261  0.047556
# 4 -0.053681 -0.043588  0.002558  ... -0.058210 -0.006885 -0.023679  0.046425
#
#         762       763       764       765       766       767
# 0 -0.001999 -0.038016 -0.014955 -0.014296 -0.001651 -0.008330
# 1 -0.014226  0.011051 -0.016975 -0.032035  0.024458 -0.010555
# 2  0.040766  0.022953 -0.072944  0.027914  0.043472  0.013049
# 3 -0.028518 -0.016287  0.047568 -0.005598  0.067882  0.000795
# 4  0.018888 -0.023683  0.020130 -0.027948 -0.010973 -0.029687
#
# [5 rows x 769 columns]
